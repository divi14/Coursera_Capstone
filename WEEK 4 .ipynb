# %% [markdown]
# # BEST LOCATION FOR OPENING A CAFE IN TORONTO

# %% [markdown]
# ### IN THIS ASSIGNMENT I WILL DETERMINE WHICH IS THE BEST LOCATION FOR OPENING A CAFE. THE CRITERIA FOR LOCATION WILL BE -:
#
# - TOURISTS SPOTS SHOULD BE NEAR TO THE LOCATION,
# - AVOID LOCATION WHERE THERE ARE LOT OF CAFES ALREADY

# %% [markdown]
# ### DATA REQUIRED
#
# - LOCATION OF TOURISTS SPOTS USING CLUSTERING
# - ALREADY EXISTING CAFES LOCATION USING FOURSQUARE
